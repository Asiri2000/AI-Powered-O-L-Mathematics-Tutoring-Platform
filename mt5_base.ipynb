# %% [markdown]
# <a href="https://colab.research.google.com/github/Asiri2000/AI-Powered-O-L-Mathematics-Tutoring-Platform/blob/model-development/mt5_base.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers

# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/google/mt5-base
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/google/mt5-base)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("t5-base")
model = AutoModelForSeq2SeqLM.from_pretrained("t5-base")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
context = """
 Finding the arc length of a sector of a circle
r
θ
C
Arc	length
180x
A B C
A
C B
The	figure	illustrates	a	sector	of	a	circle	of		radius	r.	Such	a	sector	is	called	a	sector
of	radius	r	and	angle	at	the	centre	θ. Let	us	now	consider	how	the	arc	length	of	such
a	sector	of	a	circle	is	found.
Let	us	first	find	the	arc	length	of	a	semi-circle	of	radius	r.
We	know	that	the	circumference	of	a	circle	of	radius	r	is	2πr.
Therefore,	due	to	symmetry,	the	arc	length	of	a	semi-circle	of	radius	r is	given	by

Here,	the	reason	for	taking	the	arc	length	of	the	semi-circle	to	be	πr,	that	is,	the
value	of	2πr	divided	by	2,	is	the	symmetry	of	the	circle.	The	expression	πr for
the	arc	length	of	a	semi-circle	of	radius	r	can	be	obtained	by	reasoning	out	in	the
following	manner	too.
Let	us	consider	a	circle	and	a	semi-circle,	both	of	radius	r.
r
C
360x
The	angle	at	the	centre	of	the	circle	is	360o.	The	arc	length
corresponding	to	this	angle	is	the	circumference	of	the	circle
which	is	2πr.
Now	let	us	consider	the	semi-circle.
x
r r 180
The	angle	at	the	centre	of	the	semi-circle	is	180o,	which	is
360o.	Therefore,	the	arc	length	of	the	semi-circle	should	be
the	arc	length	of	the	circle.
"""

question = "how to find arc length of a sector, give me formula"

input_text = f"question: {question} context: {context}"

inputs = tokenizer(input_text, return_tensors="pt")

outputs = model.generate(inputs.input_ids, max_length=40)

print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Let us first find the arc length of a semi-circle of radius r

# %%
text = "I love artificial intelligence"

input_text = "translate English to Sinhala: " + text

inputs = tokenizer(input_text, return_tensors="pt")

outputs = model.generate(inputs.input_ids, max_length=40)

print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Sinhala - Ich liebe künstliche Intelligenz

# %%
text = "I love artificial intelligence"

input_text = "translate English to Sinhala: " + text

inputs = tokenizer(input_text, return_tensors="pt")

outputs = model.generate(inputs.input_ids, max_length=40)

print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Sinhala - Ich liebe künstliche Intelligenz
